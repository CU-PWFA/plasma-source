# %%
# !/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Nov 26 10:15:48 2017

@author: litos
"""

import numpy as np
import nat_consts as nc
import particle_beam as pb
import plasma_source as ps
import particle_beam_propagation as pbp

    
# define plasma bulk (flat-top) properties
npl0   = 1e18                      # cm^-3, plasma density
dEds0  = np.sqrt(npl0/(5e16))*16.67e9  # eV/m, energy gain rate
dgds0  = dEds0/nc.me               # 1/m, energy gain rate for rel. gamma
L_ft   = 0.50                      # m, length of flat-top

# define plasma up-ramp
shape_up = 'gauss' # shape of ramp
hw_up    = 0.139 # 0.1403  # m, half-width of ramp
L_up     = 1.0 # m, full length of ramp
top_up   = L_up    # m, relative location of ramp top

# define plasma down-ramp
shape_dn = shape_up # shape of ramp
hw_dn    = hw_up    # m, half-width of ramp
L_dn     = L_up     # m, full length of ramp
top_dn   = 0        # m, relative location of ramp top

# define beam parameters
npart  = 0   # number of macro particles
dist   = 'gauss' # distribution shape in trace space
gbC    = (10e9)/nc.me   # centroid relativistic lorentz factor
dgb    = 0.01    # relative energy spread (HWHM)
dz     = 0       # spread in z (HWHM)
eps    = 5.0e-6  # m-rad, normalized emittance
beta   = 0.10    # m, Twiss at vac. waist
alpha  = 0.00    # Twiss at vac. waist
gamma  = (1.0+alpha**2)/beta # 1/m, Twiss at vac. waist
auto_match = False # auto-match beam to plasma flat-top

# calculate betatron wave number in flat-top
wp0    = (5.64e4)*np.sqrt(npl0) # rad/s, plasma ang. freq. (flat-top)
kp0    = wp0/nc.c               # 1/m, plasma wave number (flat-top)
kb     = kp0/np.sqrt(2*gbC)     # 1/m, betatron wave number (flat-top)

# auto-match beam to plasma flat-top
if (auto_match):
    beta   = 1.0/kb
    alpha  = 0.00    # Twiss at vac. waist
    gamma  = (1.0+alpha**2)/beta # 1/m, Twiss at vac. waist

# make beam at vac. waist
s0     = 0.0 # m
twiss  = pb.make_twiss(beta,alpha,gamma,eps,gbC,dgb,dz)
parts  = pb.make_parts(twiss[0],npart,dist)
ebeam  = pb.make_ebeam(s0,twiss[0],parts[0])

# set beam waist position
waist = (-0.3884)        # m, waist location w.r.t L_up
s_w   = L_up + waist # m, absolute wasit location

# define longitudinal steps
ds   = (1.0/kb)*(1./10.)                  # m, step size
s_ft = np.linspace(0,L_ft,int(L_ft/ds+1)) # m, steps for flat-top
s_up = np.linspace(0,L_up,int(L_up/ds+1)) # m, steps for up-ramp
s_dn = np.linspace(0,L_dn,int(L_dn/ds+1)) # m, steps for down-ramp

# make plasma
bulk    = ps.make_bulk(s_ft,npl0,dgds0)
up_ramp = ps.make_ramp(s_up,'up',shape_up,hw_up,top_up,npl0,dgds0)
dn_ramp = ps.make_ramp(s_dn,'dn',shape_dn,hw_dn,top_dn,npl0,dgds0)
plasma  = ps.make_plasma(bulk,up_ramp,dn_ramp) # output: plasma dict.

# propagate beam backward from vac. waist to start of simulation
pbp.prop_ebeam_drift(ebeam,[0,-s_w])
twiss = pb.get_twiss(ebeam,len(ebeam)-1)
parts = pb.get_parts(ebeam,len(ebeam)-1)
ebeam = pb.make_ebeam(s0,twiss[len(ebeam)-1],parts[len(ebeam)-1])
vbeam = ebeam.copy()

# propagate beam through plasma
pbp.prop_ebeam_plasma(ebeam,plasma) # output: ebeam dict.

# propagate beam through vacuum
pbp.prop_ebeam_drift(vbeam,plasma["s"]) # output: vbeam dict.

# %%
ebeam
# Out:
# defaultdict(dict,
#             {0: {'alpha': 6.1159999999999997,
#               'beta': 3.8405455999999991,
#               'dgb': -0.0,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10

#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              33: {'alpha': 6.0812704693784081,
#               'beta': 3.7981850521690688,
#               'dgb': -2.8078160774599558e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000011367,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471615536724,
#               'npart': 0,
#               's': 0.0034729530625131548,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              34: {'alpha': 6.0802180593595851,
#               'beta': 3.7969051649317778,
#               'dgb': -2.8184007834872315e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000011756,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471615254883,
#               'npart': 0,
#               's': 0.003578194064407493,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              35: {'alpha': 6.0791656493407631,
#               'beta': 3.7956254992078562,
#               'dgb': -2.82902426689373e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000012149,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471614971979,
#               'npart': 0,
#               's': 0.0036834350663018309,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              36: {'alpha': 6.0781132393219419,
#               'beta': 3.7943460549973045,
#               'dgb': -2.8396866653859945e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000012545,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471614688009,
#               'npart': 0,
#               's': 0.0037886760681961691,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              37: {'alpha': 6.0770608293031216,
#               'beta': 3.7930668323001222,
#               'dgb': -2.8503881171430325e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000012943,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.47161440297,
#               'npart': 0,
#               's': 0.003893917070090507,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              38: {'alpha': 6.0760084192843022,
#               'beta': 3.7917878311163093,
#               'dgb': -2.8611287608180243e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000013344,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471614116857,
#               'npart': 0,
#               's': 0.0039991580719848452,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              39: {'alpha': 6.0749560092654837,
#               'beta': 3.7905090514458664,
#               'dgb': -2.8719087355398147e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000013747,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471613829668,
#               'npart': 0,
#               's': 0.004104399073879183,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              40: {'alpha': 6.0739035992466661,
#               'beta': 3.7892304932887928,
#               'dgb': -2.8827281809145106e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000014154,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471613541395,
#               'npart': 0,
#               's': 0.0042096400757735209,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              41: {'alpha': 6.0728511892278494,
#               'beta': 3.7879521566450887,
#               'dgb': -2.8935872370270834e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000014564,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471613252037,
#               'npart': 0,
#               's': 0.0043148810776678596,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              42: {'alpha': 6.0717987792090335,
#               'beta': 3.7866740415147544,
#               'dgb': -2.9044860444428019e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000014978,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471612961588,
#               'npart': 0,
#               's': 0.0044201220795621974,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              43: {'alpha': 6.0707463691902186,
#               'beta': 3.7853961478977896,
#               'dgb': -2.9154247442090751e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000015394,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471612670044,
#               'npart': 0,
#               's': 0.0045253630814565352,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              44: {'alpha': 6.0696939591714045,
#               'beta': 3.7841184757941941,
#               'dgb': -2.9264034778568388e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000015813,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471612377405,
#               'npart': 0,
#               's': 0.004630604083350873,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              45: {'alpha': 6.0686415491525914,
#               'beta': 3.7828410252039686,
#               'dgb': -2.937422387402232e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000016236,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471612083664,
#               'npart': 0,
#               's': 0.0047358450852452117,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              46: {'alpha': 6.0675891391337782,
#               'beta': 3.7815637961271125,
#               'dgb': -2.9484816153480699e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.00000000001666,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471611788817,
#               'npart': 0,
#               's': 0.0048410860871395496,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              47: {'alpha': 6.0665367291149659,
#               'beta': 3.7802867885636258,
#               'dgb': -2.95958130468578e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000017089,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.47161149286,
#               'npart': 0,
#               's': 0.0049463270890338874,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              48: {'alpha': 6.0654843190961545,
#               'beta': 3.7790100025135089,
#               'dgb': -2.9707215988965935e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.00000000001752,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471611195786,
#               'npart': 0,
#               's': 0.0050515680909282252,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              49: {'alpha': 6.0644319090773449,
#               'beta': 3.7777334379767615,
#               'dgb': -2.9819026419534677e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000017955,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471610897595,
#               'npart': 0,
#               's': 0.005156809092822563,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              50: {'alpha': 6.0633794990585361,
#               'beta': 3.7764570949533836,
#               'dgb': -2.9931245783225817e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000018394,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471610598284,
#               'npart': 0,
#               's': 0.0052620500947169017,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              51: {'alpha': 6.0623270890397283,
#               'beta': 3.7751809734433754,
#               'dgb': -3.0043875529648974e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000018835,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471610297845,
#               'npart': 0,
#               's': 0.0053672910966112396,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              52: {'alpha': 6.0612746790209213,
#               'beta': 3.7739050734467368,
#               'dgb': -3.0156917113380222e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000019279,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471609996275,
#               'npart': 0,
#               's': 0.0054725320985055774,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              53: {'alpha': 6.0602222690021152,
#               'beta': 3.7726293949634675,
#               'dgb': -3.0270371993975984e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000019726,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.47160969357,
#               'npart': 0,
#               's': 0.0055777731003999152,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              54: {'alpha': 6.0591698589833101,
#               'beta': 3.7713539379935677,
#               'dgb': -3.0384241635990761e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000020178,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471609389726,
#               'npart': 0,
#               's': 0.0056830141022942539,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              55: {'alpha': 6.0581174489645058,
#               'beta': 3.7700787025370377,
#               'dgb': -3.0498527508993054e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000020632,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.47160908474,
#               'npart': 0,
#               's': 0.0057882551041885917,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              56: {'alpha': 6.0570650389457024,
#               'beta': 3.7688036885938772,
#               'dgb': -3.0613231087582637e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000021091,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471608778607,
#               'npart': 0,
#               's': 0.0058934961060829296,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              57: {'alpha': 6.0560126289269007,
#               'beta': 3.767528896164086,
#               'dgb': -3.0728353851406181e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000021553,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471608471325,
#               'npart': 0,
#               's': 0.0059987371079772674,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              58: {'alpha': 6.0549602189081,
#               'beta': 3.7662543252476648,
#               'dgb': -3.0843897285174727e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000022018,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471608162887,
#               'npart': 0,
#               's': 0.0061039781098716061,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              59: {'alpha': 6.0539078088893001,
#               'beta': 3.764979975844613,
#               'dgb': -3.0959862878678923e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000022485,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471607853287,
#               'npart': 0,
#               's': 0.0062092191117659439,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              60: {'alpha': 6.0528553988705012,
#               'beta': 3.7637058479549306,
#               'dgb': -3.1076252126808344e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000022956,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471607542524,
#               'npart': 0,
#               's': 0.0063144601136602817,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              61: {'alpha': 6.0518029888517031,
#               'beta': 3.762431941578618,
#               'dgb': -3.1193066529565695e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.00000000002343,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471607230593,
#               'npart': 0,
#               's': 0.0064197011155546196,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              62: {'alpha': 6.0507505788329059,
#               'beta': 3.7611582567156749,
#               'dgb': -3.1310307592085086e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000023908,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.47160691749,
#               'npart': 0,
#               's': 0.0065249421174489583,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              63: {'alpha': 6.0496981688141105,
#               'beta': 3.7598847933661013,
#               'dgb': -3.1427976824647816e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000024389,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471606603209,
#               'npart': 0,
#               's': 0.0066301831193432961,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              64: {'alpha': 6.048645758795316,
#               'beta': 3.7586115515298975,
#               'dgb': -3.1546075742701359e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000024874,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471606287749,
#               'npart': 0,
#               's': 0.0067354241212376339,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              65: {'alpha': 6.0475933487765214,
#               'beta': 3.7573385312070631,
#               'dgb': -3.166460586687375e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000025363,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471605971103,
#               'npart': 0,
#               's': 0.0068406651231319717,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              66: {'alpha': 6.0465409387577278,
#               'beta': 3.7560657323975981,
#               'dgb': -3.1783568722992611e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000025855,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471605653267,
#               'npart': 0,
#               's': 0.0069459061250263096,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              67: {'alpha': 6.0454885287389359,
#               'beta': 3.754793155101503,
#               'dgb': -3.190296584210137e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.00000000002635,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471605334238,
#               'npart': 0,
#               's': 0.0070511471269206483,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              68: {'alpha': 6.044436118720145,
#               'beta': 3.7535207993187774,
#               'dgb': -3.2022798760475887e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.00000000002685,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471605014009,
#               'npart': 0,
#               's': 0.0071563881288149861,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              69: {'alpha': 6.0433837087013549,
#               'beta': 3.7522486650494211,
#               'dgb': -3.2143069019643959e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000027352,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471604692579,
#               'npart': 0,
#               's': 0.0072616291307093239,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              70: {'alpha': 6.0423312986825657,
#               'beta': 3.7509767522934347,
#               'dgb': -3.2263778166399488e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.00000000002786,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471604369941,
#               'npart': 0,
#               's': 0.0073668701326036617,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              71: {'alpha': 6.0412788886637783,
#               'beta': 3.7497050610508178,
#               'dgb': -3.2384927752822547e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000028372,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471604046092,
#               'npart': 0,
#               's': 0.0074721111344980004,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              72: {'alpha': 6.0402264786449917,
#               'beta': 3.7484335913215703,
#               'dgb': -3.2506519336294114e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000028887,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471603721027,
#               'npart': 0,
#               's': 0.0075773521363923383,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              73: {'alpha': 6.0391740686262061,
#               'beta': 3.7471623431056922,
#               'dgb': -3.262855447951629e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000029406,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471603394741,
#               'npart': 0,
#               's': 0.0076825931382866761,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              74: {'alpha': 6.0381216586074213,
#               'beta': 3.745891316403184,
#               'dgb': -3.2751034750527806e-07,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000000029928,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.471603067232,
#               'npart': 0,
#               's': 0.0077878341401810139,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
# ...
#               'beta': 2.6907084363623102,
#               'dgb': -8.1508514940688729e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000040837294,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469354678284,
#               'npart': 0,
#               's': 0.10260997684697958,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              976: {'alpha': 5.0888478320486712,
#               'beta': 2.6896372147169672,
#               'dgb': -8.1785161983131e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000041111772,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469346499769,
#               'npart': 0,
#               's': 0.10271521784887391,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              977: {'alpha': 5.0877954220983934,
#               'beta': 2.6885662145849794,
#               'dgb': -8.2062715381839184e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000041388059,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469338293497,
#               'npart': 0,
#               's': 0.10282045885076825,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              978: {'alpha': 5.0867430121485526,
#               'beta': 2.6874954359663468,
#               'dgb': -8.234117799175304e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000041666167,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469330059379,
#               'npart': 0,
#               's': 0.10292569985266259,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              979: {'alpha': 5.0856906021991533,
#               'beta': 2.6864248788610694,
#               'dgb': -8.2620552676414238e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000041946107,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469321797325,
#               'npart': 0,
#               's': 0.10303094085455693,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              980: {'alpha': 5.0846381922501971,
#               'beta': 2.6853545432691468,
#               'dgb': -8.2900842307991817e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000042227892,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469313507241,
#               'npart': 0,
#               's': 0.10313618185645126,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              981: {'alpha': 5.0835857823016877,
#               'beta': 2.684284429190579,
#               'dgb': -8.3182049767306918e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000042511534,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469305189035,
#               'npart': 0,
#               's': 0.1032414228583456,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              982: {'alpha': 5.0825333723536259,
#               'beta': 2.6832145366253659,
#               'dgb': -8.346417794385689e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000042797042,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469296842617,
#               'npart': 0,
#               's': 0.10334666386023994,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              983: {'alpha': 5.0814809624060162,
#               'beta': 2.6821448655735076,
#               'dgb': -8.3747229735840756e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000043084432,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469288467895,
#               'npart': 0,
#               's': 0.10345190486213428,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              984: {'alpha': 5.0804285524588613,
#               'beta': 2.6810754160350041,
#               'dgb': -8.4031208050183519e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000043373715,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469280064775,
#               'npart': 0,
#               's': 0.10355714586402862,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              985: {'alpha': 5.0793761425121629,
#               'beta': 2.680006188009854,
#               'dgb': -8.4316115802561707e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000043664899,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469271633163,
#               'npart': 0,
#               's': 0.10366238686592295,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              986: {'alpha': 5.0783237325659254,
#               'beta': 2.6789371814980583,
#               'dgb': -8.4601955917428027e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000043958,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469263172967,
#               'npart': 0,
#               's': 0.10376762786781729,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              987: {'alpha': 5.0772713226201507,
#               'beta': 2.6778683964996168,
#               'dgb': -8.4888731328036383e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.00000004425303,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469254684092,
#               'npart': 0,
#               's': 0.10387286886971163,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              988: {'alpha': 5.0762189126748414,
#               'beta': 2.6767998330145297,
#               'dgb': -8.51764449764681e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000044550003,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469246166449,
#               'npart': 0,
#               's': 0.10397810987160597,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              989: {'alpha': 5.0751665027300019,
#               'beta': 2.6757314910427965,
#               'dgb': -8.5465099813655489e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.00000004484893,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469237619938,
#               'npart': 0,
#               's': 0.1040833508735003,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              990: {'alpha': 5.0741140927856332,
#               'beta': 2.6746633705844172,
#               'dgb': -8.5754698799419523e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000045149823,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469229044469,
#               'npart': 0,
#               's': 0.10418859187539466,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              991: {'alpha': 5.0730616828417405,
#               'beta': 2.6735954716393922,
#               'dgb': -8.604524490243838e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000045452698,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469220439943,
#               'npart': 0,
#               's': 0.10429383287728899,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              992: {'alpha': 5.0720092728983257,
#               'beta': 2.6725277942077206,
#               'dgb': -8.6336741100386183e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000045757563,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.46921180627,
#               'npart': 0,
#               's': 0.10439907387918333,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              993: {'alpha': 5.0709568629553914,
#               'beta': 2.6714603382894029,
#               'dgb': -8.662919037984503e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000046064434,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469203143351,
#               'npart': 0,
#               's': 0.10450431488107767,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              994: {'alpha': 5.0699044530129402,
#               'beta': 2.6703931038844386,
#               'dgb': -8.6922595736387649e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000046373325,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469194451092,
#               'npart': 0,
#               's': 0.10460955588297201,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              995: {'alpha': 5.0688520430709758,
#               'beta': 2.6693260909928278,
#               'dgb': -8.7216960174590894e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000046684244,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469185729395,
#               'npart': 0,
#               's': 0.10471479688486635,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              996: {'alpha': 5.0677996331295008,
#               'beta': 2.66825929961457,
#               'dgb': -8.7512286708062299e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000046997208,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469176978168,
#               'npart': 0,
#               's': 0.10482003788676068,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              997: {'alpha': 5.0667472231885187,
#               'beta': 2.6671927297496656,
#               'dgb': -8.7808578359466056e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000047312229,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469168197309,
#               'npart': 0,
#               's': 0.10492527888865502,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              998: {'alpha': 5.0656948132480313,
#               'beta': 2.6661263813981146,
#               'dgb': -8.8105838160547384e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000047629321,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469159386725,
#               'npart': 0,
#               's': 0.10503051989054936,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              999: {'alpha': 5.0646424033080439,
#               'beta': 2.6650602545599167,
#               'dgb': -8.8404069152160017e-06,
#               'dist': 'gauss',
#               'dz': 0,
#               'eps': 5e-06,
#               'gamma': 10.000000047948497,
#               'gb': array([], dtype=float64),
#               'gbC': 19569.469150546316,
#               'npart': 0,
#               's': 0.1051357608924437,
#               'x': array([], dtype=float64),
#               'xp': array([], dtype=float64),
#               'y': array([], dtype=float64),
#               'yp': array([], dtype=float64),
#               'z': array([], dtype=float64)},
#              ...})
