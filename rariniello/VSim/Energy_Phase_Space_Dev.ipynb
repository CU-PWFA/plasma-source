# %%
import sys
sys.path.insert(0, "../../python")

import os
import numpy as np
from vsim import plot
import matplotlib.pyplot as plt

path = '/media/robert/Data_Storage/VSim/FACETIITest/'
simName = 'FACETIITest'

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 30,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2
          }
plot.phase_space_energy(params)

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 0,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2,
          'Nt' : 180,
          'fps' : 25,
          'xlim' : [-25, 25],
          'ylim' : [-10, 10]
          }
plot.phase_space_energy_animation(params)
