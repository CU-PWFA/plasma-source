# %%
import sys
sys.path.insert(0, "../../python")

import os
import numpy as np
from vsim import plot
import matplotlib.pyplot as plt

path = '/media/robert/Data_Storage/VSim/FACETIIExact/'
simName = 'FACETIIBigDrive'

# %%
params = {'drive' : 'rhoDrive',
          'witness' : 'rhoWitness',
          'plasma' : 'electrons',
          'dumpInd' : 75,
          'path' : path,
          'simName' : simName,
          'zoom' : 4.0,
          'alphaCutoff' : .05
          }
plot.drive_witness_density(params)

# %%
params = {'species' : 'WitnessBeam',
          'path' : path,
          'simName' : simName,
          'Nt' : 50,
          'mass' : 0.511e-3
          }
plot.emittance_energy(params)

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 50,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2
          }
plot.phase_space(params)

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 0,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2,
          'Nt' : 75,
          'fps' : 25,
          'xlim' : [-50, 50],
          'ylim' : [-10, 10]
          }
plot.phase_space_animation(params)
plt.show()
