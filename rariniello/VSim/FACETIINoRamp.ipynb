# %%
import sys
sys.path.insert(0, "../../python")

import os
import numpy as np
from vsim import plot
import matplotlib.pyplot as plt

path = '/media/robert/Data_Storage/VSim/FACETIINoRamp/'
simName = 'FACETIINoRamp'

# %%
params = {'drive' : 'rhoDrive',
          'witness' : 'rhoWitness',
          'plasma' : 'electrons',
          'dumpInd' : 1,
          'path' : path,
          'simName' : simName,
          'zoom' : 4.0,
          'alphaCutoff' : .1,
          'Nt' : 30,
          'fps' : 20
          }
plot.drive_witness_animation(params)
plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x7f410dafe8d0>]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-bd1cac4d6f7e> in <module>()
#      10           'fps' : 20
#      11           }
# ---> 12 plot.drive_witness_animation(params)
#      13 plt.show()
#
# /home/robert/CU-PWFA/plasma-source/python/vsim/plot.py in drive_witness_animation(params)
#     243         return im1, im2, ax1
#     244
# --> 245     ani = animation.FuncAnimation(fig, updatefig, blit=True, frames=Nt)
#     246     ani.save(path+'WakefieldEvolution.mp4', fps=params['fps'])
#     247
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/animation.py in __init__(self, fig, func, frames, init_func, fargs, save_count, **kwargs)
#    1460         self._save_seq = []
#    1461
# -> 1462         TimedAnimation.__init__(self, fig, **kwargs)
#    1463
#    1464         # Need to reset the saved seq, since right now it will contain data
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1227
#    1228         Animation.__init__(self, fig, event_source=event_source,
# -> 1229                            *args, **kwargs)
#    1230
#    1231     def _step(self, *args):
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/animation.py in __init__(self, fig, event_source, blit)
#     817                                                       self._stop)
#     818         if self._blit:
# --> 819             self._setup_blit()
#     820
#     821     def _start(self, *args):
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/animation.py in _setup_blit(self)
#    1109         self._resize_id = self._fig.canvas.mpl_connect('resize_event',
#    1110                                                        self._handle_resize)
# -> 1111         self._post_draw(None, self._blit)
#    1112
#    1113     def _handle_resize(self, *args):
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#    1073             self._blit_draw(self._drawn_artists, self._blit_cache)
#    1074         else:
# -> 1075             self._fig.canvas.draw_idle()
#    1076
#    1077     # The rest of the code in this class is to facilitate easy blitting
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2030         if not self._is_idle_drawing:
#    2031             with self._idle_draw_cntx():
# -> 2032                 self.draw(*args, **kwargs)
#    2033
#    2034     def draw_cursor(self, event):
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1148
#    1149         self._cachedRenderer = renderer
# -> 1150         self.canvas.draw_event(renderer)
#    1151
#    1152     def draw_artist(self, a):
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_event(self, renderer)
#    1813         s = 'draw_event'
#    1814         event = DrawEvent(s, self, renderer)
# -> 1815         self.callbacks.process(s, event)
#    1816
#    1817     def resize_event(self):
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     547             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     548                 try:
# --> 549                     proxy(*args, **kwargs)
#     550                 except ReferenceError:
#     551                     self._remove_proxy(proxy)
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     414             mtd = self.func
#     415         # invoke the callable and return the result
# --> 416         return mtd(*args, **kwargs)
#     417
#     418     def __eq__(self, other):
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/animation.py in _start(self, *args)
#     829
#     830         # Now do any initial draw
# --> 831         self._init_draw()
#     832
#     833         # Add our callback for stepping the animation and
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/animation.py in _init_draw(self)
#    1488         # artists.
#    1489         if self._init_func is None:
# -> 1490             self._draw_frame(next(self.new_frame_seq()))
#    1491
#    1492         else:
#
# /home/robert/anaconda3/envs/CU-PWFA/lib/python3.6/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1510         # Call the func with framedata and args. If blitting is desired,
#    1511         # func needs to return a sequence of any artists that were modified.
# -> 1512         self._drawn_artists = self._func(framedata, *self._args)
#    1513         if self._blit:
#    1514             if self._drawn_artists is None:
#
# /home/robert/CU-PWFA/plasma-source/python/vsim/plot.py in updatefig(*args)
#     236         im2.set_array(witnessData)
#     237         print(ax1)
# --> 238         ax1.get_data()#plasmaZ, plasmaX)
#     239         i += 1
#     240         # If we run over, loop
#
# AttributeError: 'list' object has no attribute 'get_data'

# %%
params = {'drive' : 'rhoDrive',
          'witness' : 'rhoWitness',
          'plasma' : 'electrons',
          'dumpInd' : 25,
          'path' : path,
          'simName' : simName,
          'zoom' : 4.0,
          'alphaCutoff' : .1
          }
plot.drive_witness_density(params)

# %%
params = {'species' : 'WitnessBeam',
          'path' : path,
          'simName' : simName,
          'Nt' : 18,
          'mass' : 0.511e-3
          }
plot.emittance_energy(params)
