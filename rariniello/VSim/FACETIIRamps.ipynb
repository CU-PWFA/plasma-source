# %%
import sys
sys.path.insert(0, "../../python")

import os
import numpy as np
from vsim import plot
import matplotlib.pyplot as plt

path = '/media/robert/Data_Storage/VSim/FACETIIRamps/'
simName = 'FACETIIRamps'

# %%
params = {'drive' : 'rhoDrive',
          'witness' : 'rhoWitness',
          'plasma' : 'electrons',
          'dumpInd' : 75,
          'path' : path,
          'simName' : simName,
          'zoom' : 4.0,
          'alphaCutoff' : .05
          }
plot.drive_witness_density(params)

# %%
params = {'species' : 'WitnessBeam',
          'path' : path,
          'simName' : simName,
          'Nt' : 100,
          'mass' : 0.511e-3
          }
plot.emittance_energy(params)

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 100,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2
          }
plot.phase_space(params)

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 0,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2,
          'Nt' : 100,
          'fps' : 25,
          'xlim' : [-25, 25],
          'ylim' : [-10, 10]
          }
plot.phase_space_animation(params)

# %%
params = {'species' : 'ElectronBeam',
          'dumpInd' : 0,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2,
          'Nt' : 1000,
          'fps' : 25,
          'xlim' : [-25, 25],
          'ylim' : [-10, 10]
          }
plot.phase_space_animation(params)
