# %%
import sys
sys.path.insert(0, "../../python")

import os
import numpy as np
from vsim import plot
import matplotlib.pyplot as plt

path = '/media/robert/Data_Storage/VSim/FACETIIMatched-MatchedDrive/'
simName = 'FACETIIMatched'

# %%
params = {'drive' : 'rhoDrive',
          'witness' : 'rhoWitness',
          'plasma' : 'electrons',
          'dumpInd' : 100,
          'path' : path,
          'simName' : simName,
          'zoom' : 4.0,
          'alphaCutoff' : .05
          }
plot.drive_witness_density(params)

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 100,
          'path' : path,
          'simName' : simName,
          'cutoff' : 7.5e-2,
          'cmap' : 'jet'
          }
plot.phase_space(params)
plot.phase_space_energy(params)

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 0,
          'path' : path,
          'simName' : simName,
          'cutoff' : 7.5e-2,
          'Nt' : 100,
          'fps' : 25,
          'xlim' : [-50, 50],
          'ylim' : [-10, 10],
          'cmap' : 'jet'
          }
plot.phase_space_animation(params)
plot.phase_space_energy_animation(params)
plt.show()

# %%
path = '/media/robert/Data_Storage/VSim/FACETIIMatched-DetailedDrive/'
params = {'species' : 'ElectronBeam',
          'dumpInd' : 30,
          'path' : path,
          'simName' : simName,
          'cutoff' : 7.5e-2,
          'cmap' : 'jet'
          }
plot.phase_space(params)
plot.phase_space_energy(params)

# %%
params = {'species' : 'ElectronBeam',
          'dumpInd' : 0,
          'path' : path,
          'simName' : simName,
          'cutoff' : 7.5e-2,
          'Nt' : 30,
          'fps' : 25,
          'xlim' : [-10, 10],
          'ylim' : [-3, 3],
          'cmap' : 'jet'
          }
plot.phase_space_animation(params)
plot.phase_space_energy_animation(params)
plt.show()
