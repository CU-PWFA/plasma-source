# %%
import sys
sys.path.insert(0, "../../python")

import os
import numpy as np
from vsim import plot
import matplotlib.pyplot as plt
path = '/media/robert/Data_Storage/VSim/MatchedBeam/'
simName = 'MatchedBeam'

# %%
params = {'drive' : 'rhoDrive',
          'witness' : 'rhoWitness',
          'plasma' : 'electrons',
          'dumpInd' : 40,
          'path' : path,
          'simName' : simName,
          'zoom' : 4.0,
          'alphaCutoff' : 0.05
          }
plot.drive_witness_density(params)

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 0,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2
          }
plot.phase_space(params)

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 0,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2,
          'Nt' : 40,
          'fps' : 25,
          'xlim' : [-20, 20],
          'ylim' : [-5, 5]
          }
plot.phase_space_animation(params)

# %%
params = {'species' : 'WitnessBeam',
          'path' : path,
          'simName' : simName,
          'Nt' : 40,
          'mass' : 0.511e-3
          }
plot.emittance_energy(params)
