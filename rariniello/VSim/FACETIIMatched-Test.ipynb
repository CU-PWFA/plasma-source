# %%
import sys
sys.path.insert(0, "../../python")

import os
import numpy as np
from vsim import plot
import matplotlib.pyplot as plt

path = '/media/robert/Data_Storage/VSim/FACETIIMatched-Test/'
simName = 'FACETIIMatched'

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 1000,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2,
          'cmap' : 'jet'
          }
plot.phase_space(params)
plot.phase_space_energy(params)

# %%
params = {'species' : 'WitnessBeam',
          'dumpInd' : 0,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2,
          'Nt' : 1000,
          'fps' : 25,
          'xlim' : [-20, 20],
          'ylim' : [-5, 5],
          'cmap' : 'jet'
          }
plot.phase_space_animation(params)
plot.phase_space_energy_animation(params)
plt.show()

# %%
params = {'species' : 'ElectronBeam',
          'dumpInd' : 1000,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2,
          'cmap' : 'jet'
          }
plot.phase_space(params)
plot.phase_space_energy(params)

# %%
params = {'species' : 'ElectronBeam',
          'dumpInd' : 0,
          'path' : path,
          'simName' : simName,
          'cutoff' : 1e-2,
          'Nt' : 1000,
          'fps' : 25,
          'xlim' : [-30, 30],
          'ylim' : [-10, 10],
          'cmap' : 'jet'
          }
plot.phase_space_animation(params)
plot.phase_space_energy_animation(params)
plt.show()

# %%
params = {'species' : 'WitnessBeam',
          'path' : path,
          'simName' : simName,
          'Nt' : 1000,
          'mass' : 0.511e-3
          }
plot.emittance_energy(params)
