# %% [markdown]
# # Lithium Oven Optic 7

# %%
import sys
import os
sys.path.insert(0, "../../python")

import numpy as np
from ionization import ionization
from lens import profile
from lens import design
import matplotlib.pyplot as plt
plt.style.use('notes')
# %load_ext autoreload
# %autoreload 2

path = '/mnt/md0/Data/rariniello/Lithium_Oven/Lithium_Oven_Optic_7/'
lam = 0.796
# All length units are in um

# %% [markdown]
# 60um radius Bessel to make the widest fully ionized Bessel beam possible (see Plasma Width for details). Slightly ramping intensity profile for best performance. Plasma is approximatly 280um wide and fully ionized in the bulk. Optic 7 is an iteration of optic 6 taking into account the corrected index of lithium vapor and using an updated ionization model based on TDSE calculations, rather than the adk used for optic 6.

# %%
length = 80e4
width = 60
Nz = 2**16
Z = 100e6
z0 = 0.85e6
xlim = [0, 2.5]
tau = 70 # RMS pulse length in fs
ion = {'atom' : ionization.Li,
       'tau' : tau,
       'type' : 'gaussian'}
z, I_la = profile.cutoff_gaussian_intensity(Nz, Z, z0, length, 15e4, 6e4, 15e4, 6e4, ion, 8, 0.4, path, xlim)
# Out:
# Plasma starts at 0.26m and ends at 2.23m

# %%
# Add a ramped intensity profile
I_ramped = abs(6*I_la*(1e-6*(z-1e6)+1))
plt.figure(figsize=(8, 2), dpi=150)
plt.plot(z/1e6, I_la, 'g')
plt.plot(z/1e6, I_ramped)
plt.legend(['Original', 'Ramped'])
plt.xlabel(r'z (m)')
plt.ylabel(r'I ($\mathrm{10^{14}W/cm^2}$)')
plt.xlim(xlim)
plt.show()
np.save(path+'intensity.npy', I_ramped)
np.save(path+'z.npy', z)

# %%
r, E = design.calculate_tran_field(z, I_ramped, 20e3, width, lam, path, 10e-5, xlim, [0, 12])

# %%
# Create the gas density the laser is going into
ne0 = 3.4e16/1e17
sim_start, n_plot, n = profile.lithium_oven_profile(z, 1.25e6, ne0)
sim_length = 80e4
np.save(path+'sim_size.npy', [sim_start, sim_length])

# %%
X = 24e3
Nx = 2**13
beam0, pulseParams = design.propagate_to_start(r, E, sim_start, X, Nx, path, lam, tau, 20, [-1, 1])

# %%
Nx = 2**11
Nz = 100
X = 12e3
design.domain_test(X, Nx, sim_length, Nz, beam0, pulseParams, z, I_ramped, sim_start, [-800, 800]);

# %%
Nx = 2**11
Nz = 400
ext = [0, sim_length/1e4, -X/2, X/2]
plt.style.use('presentation')
pulse, I, ne = design.plasma_refraction(X, Nx, sim_length, Nz, beam0, pulseParams, ionization.Li, n, sim_start,
                                        1, ne0, ionization_type='lithium')
# Out:
# Initial pulse energy 7.28mJ
# Final pulse energy 4.44mJ

# %%
pulse.pulse_energy()
# Out:
# 0.0044363096884351156

# %%
design.plot_plasma_density(pulse, ne, ne0, ext, lines=[20, 40, 60])

# %%
design.plot_laser_plasma(I, ne, ext)

# %%
from lens import design
plt.style.use('notes')
design.pulse_evolution(pulse, 'Lithium_Oven_Pulse', ylim=[-500, 500], smooth=True)
# Out:
# Frame 30 completed
# Frame 60 completed
# Frame 90 completed
# Frame 120 completed
# Frame 150 completed
# Frame 180 completed
# Frame 210 completed
# Frame 240 completed
# Frame 270 completed
# Frame 300 completed
# Frame 330 completed
# Frame 360 completed
# Frame 390 completed

# %%
ind = 250
Nt = pulse.Nt
T = pulse.T
Nx = pulse.Nx
X = pulse.X
e = np.zeros((Nt, Nx), dtype='complex128')
e[:, :] = pulse.load_field(ind)[0]
I = ionization.intensity_from_field(e)
I_max = np.amax(I)
dx = X/(Nx-1)

ext = [-T/2, T/2, -X/2, X/2-dx]
plt.figure(figsize=(4, 2), dpi=300)
plt.imshow(np.fliplr(np.flipud(np.transpose(I))), aspect='auto', extent=ext, cmap='viridis', 
           interpolation='Spline16')
plt.plot([-105, 105], [0, 0], 'w--', linewidth=0.5)
plt.plot([-105, 105], [70.3, 70.3], 'w--', linewidth=0.5)
plt.plot([-105, 105], [140.6, 140.6], 'w--', linewidth=0.5)
plt.text(-100, 85, r'$x=70.3\mathrm{\mu m}$', color='w')
plt.text(-100, 160, r'$x=140.6\mathrm{\mu m}$', color='w')
cb = plt.colorbar(format="%0.2f")
cb.set_label(r'Laser Intensity ($10^{14} W/cm^2$)')
plt.xlabel('t (fs)')
plt.ylabel(r'x ($\mathrm{\mu m}$)')
plt.ylim([-500, 500])
plt.show()

# %%
ind = np.array([0, 65, 70, 80, 100, 150, 250])

Nt = pulse.Nt
T = pulse.T
t = pulse.t
Nx = pulse.Nx
X = pulse.X
e = np.zeros((Nt, Nx), dtype='complex128')

i_x = int(Nx/2)

plt.figure(figsize=(6, 3), dpi=150)
colors = [plt.cm.cool(i) for i in np.linspace(0, 1, len(ind))]
ax = plt.subplot()
ax.set_prop_cycle('color', colors)
for i in range(len(ind)):
    e[:, :] = pulse.load_field(ind[i])[0]
    I = ionization.intensity_from_field(e)
    I_max = np.amax(I)
    plt.plot(t, I[:, i_x], label='%0.2f' % (pulse.z[ind[i]]/1e4))
plt.legend(title='z (cm)')
plt.xlabel('t (fs)')
plt.ylabel(r'Laser Intensity ($10^{14} W/cm^2$)')
plt.text(-100, 0.3, 'Nice Gaussian pulse envelope')
plt.arrow(-40, 0.3, 10, -0.02, head_width=0.01, head_length=3, color=colors[0])
plt.text(-110, 0.1, "Final 'steady state' envelope")
plt.arrow(-80, 0.09, 13, -0.035, head_width=0.01, head_length=3, color=colors[-1])
plt.text(35, 0.32, 'Propagation direction')
plt.arrow(70, 0.3, -25, 0, head_width=0.01, head_length=3, color='k')
plt.title('Temporal pulse envelope at x=0um')
plt.show()

# %%
ind = np.array([0, 65, 70, 80, 100, 150, 250])

Nt = pulse.Nt
T = pulse.T
t = pulse.t
Nx = pulse.Nx
X = pulse.X
e = np.zeros((Nt, Nx), dtype='complex128')

i_x = int(Nx/2+12)
print('x=%0.1f' % (i_x/Nx*X-X/2))

plt.figure(figsize=(6, 3), dpi=150)
colors = [plt.cm.cool(i) for i in np.linspace(0, 1, len(ind))]
ax = plt.subplot()
ax.set_prop_cycle('color', colors)
for i in range(len(ind)):
    e[:, :] = pulse.load_field(ind[i])[0]
    I = ionization.intensity_from_field(e)
    I_max = np.amax(I)
    plt.plot(t, I[:, i_x], label='%0.2f' % (pulse.z[ind[i]]/1e4))
plt.legend(title='z (cm)')
plt.xlabel('t (fs)')
plt.ylabel(r'Laser Intensity ($10^{14} W/cm^2$)')
plt.text(-110, 0.01, 'Bessel ring initial intensity')
plt.arrow(-58, 0.01, 20, -0.001, head_width=0.003, head_length=3, color=colors[0], width=0.0001)
plt.text(-100, 0.07, "Final 'steady state' envelope")
plt.arrow(-44, 0.07, 12, -0.013, head_width=0.003, head_length=3, color=colors[-1], width=0.0001)
plt.text(35, 0.08, 'Propagation direction')
plt.arrow(70, 0.075, -25, 0, head_width=0.003, head_length=3, color='k', width=0.0001)
plt.title('Temporal pulse envelope at x=70um')
plt.show()
# Out:
# x=70.3

# %%
ind = np.array([0, 65, 70, 80, 100, 150, 250])

Nt = pulse.Nt
T = pulse.T
t = pulse.t
Nx = pulse.Nx
X = pulse.X
e = np.zeros((Nt, Nx), dtype='complex128')

i_x = int(Nx/2+24)
print('x=%0.1f' % (i_x/Nx*X-X/2))

plt.figure(figsize=(6, 3), dpi=150)
colors = [plt.cm.cool(i) for i in np.linspace(0, 1, len(ind))]
ax = plt.subplot()
ax.set_prop_cycle('color', colors)
for i in range(len(ind)):
    e[:, :] = pulse.load_field(ind[i])[0]
    I = ionization.intensity_from_field(e)
    I_max = np.amax(I)
    plt.plot(t, I[:, i_x], label='%0.2f' % (pulse.z[ind[i]]/1e4))
plt.legend(title='z (cm)')
plt.xlabel('t (fs)')
plt.ylabel(r'Laser Intensity ($10^{14} W/cm^2$)')
plt.text(-90, 0.01, 'No initial intensity')
plt.arrow(-52, 0.01, 20, -0.008, head_width=0.0015, head_length=3, color=colors[0], width=0.0001)
plt.text(-110, 0.028, "Pre-pulse barely ionizes anything")
plt.arrow(-44, 0.028, 8, -0.002, head_width=0.0015, head_length=3, color=colors[-1], width=0.0001)
plt.text(-70, 0.04, "Main pulse does the ionizing")
plt.arrow(-14, 0.04, 24, -0.002, head_width=0.0015, head_length=3, color=colors[-1], width=0.0001)
plt.text(35, 0.04, 'Propagation direction')
plt.arrow(70, 0.038, -25, 0, head_width=0.0015, head_length=3, color='k', width=0.0001)
plt.title('Temporal pulse envelope at x=140um')
plt.show()
# Out:
# x=140.6

# %%
ind = 250

Nt = pulse.Nt
T = pulse.T
t = pulse.t
Nx = pulse.Nx
X = pulse.X
e = np.zeros((Nt, Nx), dtype='complex128')

i_x = int(Nx/2)
i_x2 = int(Nx/2+12)
print('x=%0.1f' % (i_x/Nx*X-X/2))

plt.figure(figsize=(6, 3), dpi=150)
#colors = [plt.cm.cool(i) for i in np.linspace(0, 1, len(ind))]
#ax = plt.subplot()
#ax.set_prop_cycle('color', colors)
e[:, :] = pulse.load_field(ind)[0]
I = ionization.intensity_from_field(e)
I_max = np.amax(I)
plt.plot(t, I[:, i_x], label=r'$x=0\mathrm{\mu m}$')
plt.plot(t-25, I[:, i_x2], label=r'$x=70\mathrm{\mu m}$')
plt.legend()
plt.xlabel('t (fs)')
plt.ylabel(r'Laser Intensity ($10^{14} W/cm^2$)')
plt.title('Steady state pulse shape at x=0um and x=70um')
plt.text(-20, 0.04, 'The 70um curve has been shifted so the peaks line up')
plt.text(15, 0.058, 'Propagation direction')
plt.arrow(55, 0.055, -25, 0, head_width=0.0015, head_length=3, color='k', width=0.0001)
plt.show()
# Out:
# x=0.0

# %%
Nt = pulse.Nt
T = pulse.T
t = pulse.t
Nx = pulse.Nx
X = pulse.X
e = np.zeros((Nt, Nx), dtype='complex128')

# First on axis envelope
i_x = int(Nx/2)
e[:, :] = pulse.load_field(0)[0]
np.save('t.npy', t)
np.save('x=0um_z=0cm_InitialGaussian.npy', abs(e[:, i_x]))

e[:, :] = pulse.load_field(250)[0]
np.save('x=0um_z=50cm_PulseShape.npy', abs(e[:, i_x]))

i_x = int(Nx/2+16)
e[:, :] = pulse.load_field(250)[0]
np.save('x=70um_z=50cm_PulseShape.npy', abs(e[:, i_x]))
